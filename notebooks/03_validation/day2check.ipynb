# %%
spark.sql("SHOW TABLES IN insurance_lakehouse.silver").show(truncate=False)

# %%
spark.sql("SHOW TABLES IN insurance_lakehouse.quarantine").show(truncate=False)

# %%
print("insurance_lakehouse.bronze.bronze_customers :",spark.table("insurance_lakehouse.bronze.bronze_customers").count())
print("insurance_lakehouse.silver.silver_customers :",spark.table("insurance_lakehouse.silver.silver_customers").count())

# %%
spark.table("insurance_lakehouse.silver.silver_customers").printSchema()

# %%
spark.sql("SHOW TABLES IN insurance_lakehouse.silver").show(truncate=False)

spark.sql("SHOW TABLES IN insurance_lakehouse.quarantine").show(truncate=False)

print("insurance_lakehouse.bronze.bronze_customers",spark.table("insurance_lakehouse.bronze.bronze_customers").count())
print("insurance_lakehouse.silver.silver_customers",spark.table("insurance_lakehouse.silver.silver_customers").count())

print("insurance_lakehouse.bronze.bronze_policies",spark.table("insurance_lakehouse.bronze.bronze_policies").count())
print("insurance_lakehouse.silver.silver_policies",spark.table("insurance_lakehouse.silver.silver_policies").count())

print("insurance_lakehouse.bronze.bronze_claims",spark.table("insurance_lakehouse.bronze.bronze_claims").count())
print("insurance_lakehouse.silver.silver_claims",spark.table("insurance_lakehouse.silver.silver_claims").count())

print(spark.table("insurance_lakehouse.bronze.bronze_payments").count())
print(spark.table("insurance_lakehouse.silver.silver_payments").count())

print("insurance_lakehouse.bronze.bronze_agents",spark.table("insurance_lakehouse.bronze.bronze_agents").count())
print("insurance_lakehouse.silver.silver_agents",spark.table("insurance_lakehouse.silver.silver_agents").count())

print("insurance_lakehouse.bronze.bronze_fraud_indicators",spark.table("insurance_lakehouse.bronze.bronze_fraud_indicators").count())
print("insurance_lakehouse.silver.silver_fraud_indicators",spark.table("insurance_lakehouse.silver.silver_fraud_indicators").count())

spark.table("insurance_lakehouse.silver.silver_customers").printSchema()

spark.table("insurance_lakehouse.quarantine.quarantine_invalid_payments").show(5)

spark.table("insurance_lakehouse.quarantine.quarantine_invalid_customers").show(5)

spark.table("insurance_lakehouse.quarantine.quarantine_invalid_policies").show(5)

spark.table("insurance_lakehouse.quarantine.quarantine_invalid_claims").show(5)
